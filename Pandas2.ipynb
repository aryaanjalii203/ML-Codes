# %% [markdown]
# <a href="https://colab.research.google.com/github/aryaanjalii203/ML-Codes/blob/main/Pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("student_dataset.csv")

# %%
df.head()
# Out:
#    Student_ID   Name  Age Gender  Math_Score  Science_Score  English_Score  \
# 0           1  Aarav   15      M          78             82             75
# 1           2   Diya   16      F          85             88             80
# 2           3  Rahul   15      M          69             70             72
# 3           4  Sneha   17      F          90             92             85
# 4           5  Karan   16      M          72             75             70
#
#    Attendance_Percentage  Passed
# 0                     92    True
# 1                     95    True
# 2                     88    True
# 3                     98    True
# 4                     85    True

# %% [markdown]
# 20 starting rows

# %%
df.head(20)
# Out:
#     Student_ID    Name  Age Gender  Math_Score  Science_Score  English_Score  \
# 0            1   Aarav   15      M          78             82             75
# 1            2    Diya   16      F          85             88             80
# 2            3   Rahul   15      M          69             70             72
# 3            4   Sneha   17      F          90             92             85
# 4            5   Karan   16      M          72             75             70
# 5            6  Ananya   15      F          88             90             83
# 6            7   Rohit   17      M          65             68             74
# 7            8   Pooja   16      F          91             94             88
# 8            9  Vikram   18      M          74             77             76
# 9           10    Neha   15      F          86             89             82
# 10          11    Amit   16      M          80             83             78
# ...

# %% [markdown]
# 20 rows and 9 columns

# %%
df.shape
# Out:
# (20, 9)

# %%
df.columns
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Gender', 'Math_Score', 'Science_Score',
#        'English_Score', 'Attendance_Percentage', 'Passed'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             20 non-null     int64
#  1   Name                   20 non-null     object
#  2   Age                    20 non-null     int64
#  3   Gender                 20 non-null     object
#  4   Math_Score             20 non-null     int64
#  5   Science_Score          20 non-null     int64
#  6   English_Score          20 non-null     int64
#  7   Attendance_Percentage  20 non-null     int64
#  8   Passed                 20 non-null     bool
# dtypes: bool(1), int64(6), object(2)
# memory usage: 1.4+ KB

# %%
df.dtypes
# Out:
# Student_ID                int64
# Name                     object
# Age                       int64
# Gender                   object
# Math_Score                int64
# Science_Score             int64
# English_Score             int64
# Attendance_Percentage     int64
# Passed                     bool
# dtype: object

# %%
numerical_df=df.select_dtypes(include=["int64","float64"])
numerical_df
# Out:
#     Student_ID  Age  Math_Score  Science_Score  English_Score  \
# 0            1   15          78             82             75
# 1            2   16          85             88             80
# 2            3   15          69             70             72
# 3            4   17          90             92             85
# 4            5   16          72             75             70
# 5            6   15          88             90             83
# 6            7   17          65             68             74
# 7            8   16          91             94             88
# 8            9   18          74             77             76
# 9           10   15          86             89             82
# 10          11   16          80             83             78
# 11          12   17          92             95             90
# 12          13   15          68             72             73
# 13          14   16          89             91             86
# ...

# %%
import numpy as np

# %%
num_array=numerical_df.to_numpy()
num_array
# Out:
# array([[ 1, 15, 78, 82, 75, 92],
#        [ 2, 16, 85, 88, 80, 95],
#        [ 3, 15, 69, 70, 72, 88],
#        [ 4, 17, 90, 92, 85, 98],
#        [ 5, 16, 72, 75, 70, 85],
#        [ 6, 15, 88, 90, 83, 96],
#        [ 7, 17, 65, 68, 74, 80],
#        [ 8, 16, 91, 94, 88, 99],
#        [ 9, 18, 74, 77, 76, 90],
#        [10, 15, 86, 89, 82, 94],
#        [11, 16, 80, 83, 78, 93],
#        [12, 17, 92, 95, 90, 97],
#        [13, 15, 68, 72, 73, 86],
#        [14, 16, 89, 91, 86, 96],
#        [15, 18, 76, 79, 79, 91],
#        [16, 17, 90, 93, 87, 98],
#        [17, 16, 73, 76, 75, 89],
#        [18, 15, 84, 86, 81, 92],
#        [19, 17, 79, 81, 77, 90],
#        [20, 16, 87, 90, 84, 95]])

# %%
num_array.shape
# Out:
# (20, 6)

# %% [markdown]
# Average of every column

# %%
np.mean(num_array,axis=0)
# Out:
# array([10.5 , 16.15, 80.8 , 83.55, 79.75, 92.2 ])

# %%
np.max(num_array, axis=0)
# Out:
# array([20, 18, 92, 95, 90, 99])

# %%
np.max(num_array)
# Out:
# np.int64(99)

# %%
np.min(num_array,axis=0)
# Out:
# array([ 1, 15, 65, 68, 70, 80])

# %%
np.min(num_array)
# Out:
# np.int64(1)

# %%
df["Math_Score"]>85
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5      True
# 6     False
# 7      True
# 8     False
# 9      True
# 10    False
# 11     True
# 12    False
# 13     True
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19     True
# Name: Math_Score, dtype: bool

# %%
df[df["Math_Score"]>85]
# Out:
#     Student_ID    Name  Age Gender  Math_Score  Science_Score  English_Score  \
# 3            4   Sneha   17      F          90             92             85
# 5            6  Ananya   15      F          88             90             83
# 7            8   Pooja   16      F          91             94             88
# 9           10    Neha   15      F          86             89             82
# 11          12    Isha   17      F          92             95             90
# 13          14    Riya   16      F          89             91             86
# 15          16   Kriti   17      F          90             93             87
# 19          20   Priya   16      F          87             90             84
#
#     Attendance_Percentage  Passed
# 3                      98    True
# 5                      96    True
# 7                      99    True
# 9                      94    True
# 11                     97    True
# 13                     96    True
# ...

# %%
df[(df["Math_Score"]>80) & (df["Science_Score"]>85)]
# Out:
#     Student_ID    Name  Age Gender  Math_Score  Science_Score  English_Score  \
# 1            2    Diya   16      F          85             88             80
# 3            4   Sneha   17      F          90             92             85
# 5            6  Ananya   15      F          88             90             83
# 7            8   Pooja   16      F          91             94             88
# 9           10    Neha   15      F          86             89             82
# 11          12    Isha   17      F          92             95             90
# 13          14    Riya   16      F          89             91             86
# 15          16   Kriti   17      F          90             93             87
# 17          18   Tanya   15      F          84             86             81
# 19          20   Priya   16      F          87             90             84
#
#     Attendance_Percentage  Passed
# 1                      95    True
# 3                      98    True
# ...

# %%
df.iloc[0:5]
# Out:
#    Student_ID   Name  Age Gender  Math_Score  Science_Score  English_Score  \
# 0           1  Aarav   15      M          78             82             75
# 1           2   Diya   16      F          85             88             80
# 2           3  Rahul   15      M          69             70             72
# 3           4  Sneha   17      F          90             92             85
# 4           5  Karan   16      M          72             75             70
#
#    Attendance_Percentage  Passed
# 0                     92    True
# 1                     95    True
# 2                     88    True
# 3                     98    True
# 4                     85    True

# %%
df.iloc[0:5, 0:4]
# Out:
#    Student_ID   Name  Age Gender
# 0           1  Aarav   15      M
# 1           2   Diya   16      F
# 2           3  Rahul   15      M
# 3           4  Sneha   17      F
# 4           5  Karan   16      M

# %%
df.loc[3]
# Out:
# Student_ID                   4
# Name                     Sneha
# Age                         17
# Gender                       F
# Math_Score                  90
# Science_Score               92
# English_Score               85
# Attendance_Percentage       98
# Passed                    True
# Name: 3, dtype: object

# %%
df.iloc[3]
# Out:
# Student_ID                   4
# Name                     Sneha
# Age                         17
# Gender                       F
# Math_Score                  90
# Science_Score               92
# English_Score               85
# Attendance_Percentage       98
# Passed                    True
# Name: 3, dtype: object

# %%
df2=df.set_index("Student_ID")

# %%
df2.head()
# Out:
#              Name  Age Gender  Math_Score  Science_Score  English_Score  \
# Student_ID
# 1           Aarav   15      M          78             82             75
# 2            Diya   16      F          85             88             80
# 3           Rahul   15      M          69             70             72
# 4           Sneha   17      F          90             92             85
# 5           Karan   16      M          72             75             70
#
#             Attendance_Percentage  Passed
# Student_ID
# 1                              92    True
# 2                              95    True
# 3                              88    True
# 4                              98    True
# 5                              85    True

# %% [markdown]
# it goes according row position

# %%
df2.loc[3]
# Out:
# Name                     Rahul
# Age                         15
# Gender                       M
# Math_Score                  69
# Science_Score               70
# English_Score               72
# Attendance_Percentage       88
# Passed                    True
# Name: 3, dtype: object

# %% [markdown]
# It goes according to index

# %%
df2.iloc[3]
# Out:
# Name                     Sneha
# Age                         17
# Gender                       F
# Math_Score                  90
# Science_Score               92
# English_Score               85
# Attendance_Percentage       98
# Passed                    True
# Name: 4, dtype: object

# %%
df.loc[:,["Name","Math_Score","Science_Score"]]
# Out:
#       Name  Math_Score  Science_Score
# 0    Aarav          78             82
# 1     Diya          85             88
# 2    Rahul          69             70
# 3    Sneha          90             92
# 4    Karan          72             75
# 5   Ananya          88             90
# 6    Rohit          65             68
# 7    Pooja          91             94
# 8   Vikram          74             77
# 9     Neha          86             89
# 10    Amit          80             83
# 11    Isha          92             95
# 12   Sahil          68             72
# 13    Riya          89             91
# 14   Arjun          76             79
# 15   Kriti          90             93
# 16  Manish          73             76
# 17   Tanya          84             86
# 18  Nikhil          79             81
# 19   Priya          87             90

# %%
df["Total_Score"]=df["Math_Score"]+df["Science_Score"]+df["English_Score"]
print(df["Total_Score"])
# Out:
# 0     235
# 1     253
# 2     211
# 3     267
# 4     217
# 5     261
# 6     207
# 7     273
# 8     227
# 9     257
# 10    241
# 11    277
# 12    213
# 13    266
# 14    234
# 15    270
# 16    224
# 17    251
# 18    237
# 19    261
# Name: Total_Score, dtype: int64

# %%
df["Average_Score"]=df["Total_Score"]/3
print(df["Average_Score"])
# Out:
# 0     78.333333
# 1     84.333333
# 2     70.333333
# 3     89.000000
# 4     72.333333
# 5     87.000000
# 6     69.000000
# 7     91.000000
# 8     75.666667
# 9     85.666667
# 10    80.333333
# 11    92.333333
# 12    71.000000
# 13    88.666667
# 14    78.000000
# 15    90.000000
# 16    74.666667
# 17    83.666667
# 18    79.000000
# 19    87.000000
# Name: Average_Score, dtype: float64

# %%
df.groupby("Gender")["Average_Score"].mean()
# Out:
# Gender
# F    87.866667
# M    74.866667
# Name: Average_Score, dtype: float64
